# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/local/companies/silver_001.parquet")

df.head()
# Out:
# Index(['company_id', 'linkedin_id', 'name', 'slogan', 'headquarters',
#        'country_code', 'website', 'website_domain', 'linkedin_url', 'about',
#        'industries', 'specialties', 'organization_type', 'company_size',
#        'founded_year', 'followers', 'employees_on_linkedin', 'locations_json',
#        'formatted_locations_json', 'country_codes_json', 'logo_url',
#        'cover_image_url', 'funding_last_round_date', 'funding_last_round_type',
#        'funding_rounds_count', 'funding_last_round_amount', 'crunchbase_url',
#        'employees_json', 'similar_companies_json', 'affiliated_pages_json',
#        'updates_json', 'employees_featured_count', 'similar_companies_count',
#        'affiliated_pages_count', 'updates_count', 'has_funding_info',
#        'latest_update_date', 'snapshot_date', 'scraped_at', 'source_url',
#        'processed_at'],
#       dtype='object')
